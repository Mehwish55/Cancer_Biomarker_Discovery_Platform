# %%
setwd("/mnt/d/Cancer_Biomarker_Project")

# %%
getwd()
# Out:
# [1] "/mnt/d/Cancer_Biomarker_Project"

# %%
list.files("data/processed")
# Out:
# [1] "significant_genes_TCGA_LUAD.csv"

# %%
install.packages(c(
  "tidyverse",
  "data.table",
  "pheatmap",
  "BiocManager"
))
# Out:
# Installing packages into ‘/home/mehwish/R/x86_64-pc-linux-gnu-library/4.5’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘ps’, ‘sass’, ‘rematch’, ‘otel’, ‘processx’, ‘bslib’, ‘backports’, ‘gargle’, ‘cellranger’, ‘ids’, ‘rematch2’, ‘timechange’, ‘textshaping’, ‘callr’, ‘rmarkdown’, ‘broom’, ‘conflicted’, ‘dtplyr’, ‘forcats’, ‘googledrive’, ‘googlesheets4’, ‘haven’, ‘lubridate’, ‘modelr’, ‘ragg’, ‘readxl’, ‘reprex’, ‘rstudioapi’, ‘rvest’, ‘xml2’
#
#
# Warning message in install.packages(c("tidyverse", "data.table", "pheatmap", "BiocManager")):
# “installation of package ‘xml2’ had non-zero exit status”
# Warning message in install.packages(c("tidyverse", "data.table", "pheatmap", "BiocManager")):
# “installation of package ‘ragg’ had non-zero exit status”
# Warning message in install.packages(c("tidyverse", "data.table", "pheatmap", "BiocManager")):
# “installation of package ‘rvest’ had non-zero exit status”
# ...

# %%
library(DESeq2)
library(clusterProfiler)
library(org.Hs.eg.db)
library(enrichplot)
library(data.table)
library(dplyr)
library(ggplot2)
# Out:
# Loading required package: S4Vectors
#
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
# Loading required package: generics
#
#
# Attaching package: ‘generics’
#
#
# The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
#
#
# Attaching package: ‘S4Vectors’
#
#
# ...

# %%
getwd()
# Out:
# [1] "/mnt/d/Cancer_Biomarker_Project/notebooks"

# %%
list.files("data/processed")
# Out:
# character(0)

# %%
print(list.files("data/processed"))
# Out:
# character(0)

# %%
list.files("data/processed")
# Out:
# character(0)

# %%
print(list.files("data/processed"))
# Out:
# character(0)

# %%
1 + 1
# Out:
# [1] 2

# %%
getwd()
# Out:
# [1] "/mnt/d/Cancer_Biomarker_Project/notebooks"

# %%
library(data.table)

genes <- fread("data/processed/significant_genes_TCGA_LUAD.csv")

head(genes)
# Out:
#   V1                 baseMean   log2FoldChange lfcSE     stat
# 1 ENSG00000147689.16  6257.3020  6.791700      0.2369153  28.66720
# 2 ENSG00000183010.17  3613.0537  3.687783      0.1328495  27.75910
# 3 ENSG00000165312.6   1098.8338 -2.120458      0.0813114 -26.07824
# 4 ENSG00000272620.2   2784.3456  6.305807      0.2572528  24.51211
# 5 ENSG00000116016.14 26990.0058 -2.723979      0.1113997 -24.45230
# 6 ENSG00000135604.10   805.3661 -3.067332      0.1258437 -24.37414
#   pvalue        padj          gene_name
# 1 9.785412e-181 4.296774e-176 FAM83A
# 2 1.353073e-169 2.970671e-165 PYCR1
# 3 6.437082e-150 9.421742e-146 OTUD1
# 4 1.097382e-132 1.204652e-128 AFAP1-AS1
# 5 4.757257e-132 4.177823e-128 EPAS1
# 6 3.216347e-131 2.353830e-127 STX11

# %%
dim(genes)
# Out:
# [1] 15152     8

# %%
colnames(genes)
# Out:
# [1] "V1"             "baseMean"       "log2FoldChange" "lfcSE"
# [5] "stat"           "pvalue"         "padj"           "gene_name"

# %%
library(dplyr)

sig_genes <- genes %>%
  filter(padj < 0.05) %>%
  pull(gene_name)

head(sig_genes)
length(sig_genes)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:data.table’:
#
#     between, first, last
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [1] "FAM83A"    "PYCR1"     "OTUD1"     "AFAP1-AS1" "EPAS1"     "STX11"
# [1] 15152

# %%
head(sig_genes, 20)
# Out:
#  [1] "FAM83A"     "PYCR1"      "OTUD1"      "AFAP1-AS1"  "EPAS1"
#  [6] "STX11"      "SPAAR"      "PECAM1"     "ETV4"       "TEDC2"
# [11] "IQGAP3"     "TOP2A"      "S1PR1"      "FAM83A-AS1" "B3GNT3"
# [16] "RGCC"       "ACVRL1"     "EMP2"       "SEMA3G"     "RTKN2"

# %%
if (!require("BiocManager")) {
    install.packages("BiocManager")
}

BiocManager::install(c(
    "clusterProfiler",
    "org.Hs.eg.db",
    "enrichplot"
))
# Out:
# Loading required package: BiocManager
#
# Bioconductor version '3.22' is out-of-date; the current release version '3.23'
#   is available with R version '4.6'; see https://bioconductor.org/install
#
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cloud.r-project.org
#
# Bioconductor version 3.22 (BiocManager 1.30.27), R 4.5.2 (2025-10-31)
#
# Installing package(s) 'clusterProfiler', 'org.Hs.eg.db', 'enrichplot'
#
# also installing the dependencies ‘gdtools’, ‘htmlwidgets’, ‘ggplotify’, ‘tidytree’, ‘treeio’, ‘ggiraph’, ‘DOSE’, ‘GOSemSim’, ‘gson’, ‘igraph’, ‘yulab.utils’, ‘aplot’, ‘ggfun’, ‘ggtangle’, ‘tidydr’, ‘scatterpie’, ‘ggtree’
#
#
# Warning message in install.packages(...):
# “installation of package ‘gdtools’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘igraph’ had non-zero exit status”
# ...

# %%
.libPaths()
# Out:
# [1] "/home/mehwish/R/x86_64-pc-linux-gnu-library/4.5"
# [2] "/usr/local/lib/R/site-library"
# [3] "/usr/lib/R/site-library"
# [4] "/usr/lib/R/library"

# %%
install.packages("BiocManager", lib="/home/mehwish/R/x86_64-pc-linux-gnu-library/4.5")

# %%
q()
