# %%
if (!requireNamespace("BiocManager", quietly = TRUE))
    install.packages("BiocManager")

BiocManager::install("TCGAbiolinks")
# Out:
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cran.r-project.org
#
# Bioconductor version 3.18 (BiocManager 1.30.27), R 4.3.3 (2024-02-29)
#
# Installing package(s) 'BiocVersion', 'TCGAbiolinks'
#
# also installing the dependencies ‘prettyunits’, ‘dbplyr’, ‘filelock’, ‘progress’, ‘BiocFileCache’, ‘selectr’, ‘R.oo’, ‘R.methodsS3’, ‘clipr’, ‘hms’, ‘vroom’, ‘tzdb’, ‘biomaRt’, ‘XML’, ‘rvest’, ‘R.utils’, ‘TCGAbiolinksGUI.data’, ‘readr’, ‘xml2’
#
#
# Warning message in install.packages(...):
# “installation of package ‘dbplyr’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘filelock’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘tzdb’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘XML’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘xml2’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘BiocFileCache’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘rvest’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘vroom’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘biomaRt’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘readr’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘TCGAbiolinks’ had non-zero exit status”
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
# Old packages: 'abind', 'aplot', 'base64enc', 'BH', 'Biostrings', 'bit64',
#   'bitops', 'blob', 'bslib', 'cli', 'clusterProfiler', 'colorspace', 'cpp11',
#   'curl', 'data.table', 'DBI', 'DESeq2', 'digest', 'DOSE', 'dplyr', 'ellipsis',
#   'fansi', 'fastmatch', 'fs', 'futile.logger', 'GenomeInfoDb', 'ggfun',
#   'ggiraph', 'ggplot2', 'ggraph', 'ggrepel', 'ggtree', 'glue', 'GOSemSim',
#   'graphlayouts', 'gridExtra', 'gson', 'highr', 'htmltools', 'httr', 'httr2',
#   'igraph', 'irlba', 'isoband', 'knitr', 'lattice', 'lazyeval', 'lifecycle',
#   'magrittr', 'mvtnorm', 'nlme', 'openssl', 'pillar', 'png', 'purrr',
#   'rappdirs', 'Rcpp', 'RcppArmadillo', 'RcppNumerical', 'RCurl', 'reshape2',
#   'rlang', 'rmarkdown', 'RSQLite', 'S4Arrays', 'S7', 'SparseArray', 'SQUAREM',
#   'stringi', 'stringr', 'systemfonts', 'tibble', 'tidygraph', 'tidyr',
#   'tidytree', 'tinytex', 'uuid', 'vctrs', 'viridisLite', 'withr', 'xfun',
#   'yaml', 'yulab.utils', 'zlibbioc'

# %%
R.version.string
# Out:
# [1] "R version 4.3.3 (2024-02-29)"

# %%
BiocManager::version()
# Out:
# [1] ‘3.18’

# %%
install.packages(c(
  "rvest",
  "vroom",
  "readr"
))
# Out:
# also installing the dependencies ‘xml2’, ‘tzdb’
#
#
# Warning message in install.packages(c("rvest", "vroom", "readr")):
# “installation of package ‘xml2’ had non-zero exit status”
# Warning message in install.packages(c("rvest", "vroom", "readr")):
# “installation of package ‘tzdb’ had non-zero exit status”
# Warning message in install.packages(c("rvest", "vroom", "readr")):
# “installation of package ‘rvest’ had non-zero exit status”
# Warning message in install.packages(c("rvest", "vroom", "readr")):
# “installation of package ‘vroom’ had non-zero exit status”
# Warning message in install.packages(c("rvest", "vroom", "readr")):
# “installation of package ‘readr’ had non-zero exit status”
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done

# %%
library(TCGAbiolinks)
# Out:
# Error in library(TCGAbiolinks): there is no package called ‘TCGAbiolinks’
# Traceback:
#
# 1. stop(packageNotFoundError(package, lib.loc, sys.call()))
